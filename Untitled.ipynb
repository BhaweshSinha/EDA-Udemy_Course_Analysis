# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
df = pd.read_csv('udemy_courses.csv')

# %%
df.head(3)
# Out:
#    course_id                                       course_title
# 0    1070968                 Ultimate Investment Banking Course  \
# 1    1113822  Complete GST Course & Certification - Grow You...
# 2    1006314  Financial Modeling for Business Analysts and C...
#
#                                                  url  is_paid  price
# 0  https://www.udemy.com/ultimate-investment-bank...     True    200  \
# 1      https://www.udemy.com/goods-and-services-tax/     True     75
# 2  https://www.udemy.com/financial-modeling-for-b...     True     45
#
#    num_subscribers  num_reviews  num_lectures               level
# 0             2147           23            51          All Levels  \
# 1             2792          923           274          All Levels
# 2             2174           74            51  Intermediate Level
#
#    content_duration   published_timestamp           subject
# 0               1.5  2017-01-18T20:58:58Z  Business Finance
# 1              39.0  2017-03-09T16:34:20Z  Business Finance
# 2               2.5  2016-12-19T19:26:30Z  Business Finance

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3678 entries, 0 to 3677
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   course_id            3678 non-null   int64
#  1   course_title         3678 non-null   object
#  2   url                  3678 non-null   object
#  3   is_paid              3678 non-null   bool
#  4   price                3678 non-null   int64
#  5   num_subscribers      3678 non-null   int64
#  6   num_reviews          3678 non-null   int64
#  7   num_lectures         3678 non-null   int64
#  8   level                3678 non-null   object
#  9   content_duration     3678 non-null   float64
#  10  published_timestamp  3678 non-null   object
#  11  subject              3678 non-null   object
# dtypes: bool(1), float64(1), int64(5), object(5)
# memory usage: 319.8+ KB

# %%
df.isnull().sum()
df.head(5)
# Out:
#    course_id                                       course_title
# 0    1070968                 Ultimate Investment Banking Course  \
# 1    1113822  Complete GST Course & Certification - Grow You...
# 2    1006314  Financial Modeling for Business Analysts and C...
# 3    1210588  Beginner to Pro - Financial Analysis in Excel ...
# 4    1011058       How To Maximize Your Profits Trading Options
#
#                                                  url  is_paid  price
# 0  https://www.udemy.com/ultimate-investment-bank...     True    200  \
# 1      https://www.udemy.com/goods-and-services-tax/     True     75
# 2  https://www.udemy.com/financial-modeling-for-b...     True     45
# 3  https://www.udemy.com/complete-excel-finance-c...     True     95
# 4  https://www.udemy.com/how-to-maximize-your-pro...     True    200
#
#    num_subscribers  num_reviews  num_lectures               level
# 0             2147           23            51          All Levels  \
# 1             2792          923           274          All Levels
# 2             2174           74            51  Intermediate Level
# 3             2451           11            36          All Levels
# 4             1276           45            26  Intermediate Level
#
#    content_duration   published_timestamp           subject
# 0               1.5  2017-01-18T20:58:58Z  Business Finance
# 1              39.0  2017-03-09T16:34:20Z  Business Finance
# 2               2.5  2016-12-19T19:26:30Z  Business Finance
# 3               3.0  2017-05-30T20:07:24Z  Business Finance
# 4               2.0  2016-12-13T14:57:18Z  Business Finance

# %%
#Finding out the duplicates
df[df['course_title'] == 'Essentials of money: Get a financial Life !']
# Out:
# Empty DataFrame
# Columns: [course_id, course_title, url, is_paid, price, num_subscribers, num_reviews, num_lectures, level, content_duration, published_timestamp, subject]
# Index: []

# %%
df['subject'].value_counts()
# Out:
# subject
# Web Development        1200
# Business Finance       1195
# Musical Instruments     680
# Graphic Design          603
# Name: count, dtype: int64

# %%
plt.figure(figsize=(8,8))
sns.countplot(data=df,x='subject')
plt.xlabel('SUBJECTS')
plt.ylabel('NUMBER OF COURSES(subject wise)')
# Out:
# Text(0, 0.5, 'NUMBER OF COURSES(subject wise)')

# %%
sns.countplot(x = 'level',data = df)
plt.ylabel('NUMBER OF COURSES(LEVEL WISE)')
# Out:
# Text(0, 0.5, 'NUMBER OF COURSES(LEVEL WISE)')

# %%
#Pie plot
df_level = df['level'].value_counts()
plt.pie(df_level,normalize = True, autopct = '%1.1f%%', labels = df_level.index)
plt.show()

# %%
#Number of lectures are free and paid
df.groupby('is_paid')['num_lectures'].sum()
# Out:
# is_paid
# False      6639
# True     140881
# Name: num_lectures, dtype: int64

# %%
#lets visulaize it along with levels

sns.barplot(data = df, x = 'level', y = 'num_lectures',hue = 'is_paid')
# Out:
# <Axes: xlabel='level', ylabel='num_lectures'>

# %%
df.groupby('level')['num_subscribers'].sum()
# Out:
# level
# All Levels            6915076
# Beginner Level        4051843
# Expert Level            50196
# Intermediate Level     742005
# Name: num_subscribers, dtype: int64

# %%
'''Visualizing
1. Finding the most enrolled course
2. Top #10 popular courses
3. Courses having highest rating
'''
# Out:
# 'Visualizing\n1. Finding the most enrolled course\n2. Top #10 popular courses\n3. Courses having highest rating\n4. Year wise revenue by udemy\n'

# %%
#Finding the most enrolled course
df.groupby('course_title')['num_subscribers'].sum().sort_values(ascending = False).head(1)
# Out:
# course_title
# Learn HTML5 Programming From Scratch    268923
# Name: num_subscribers, dtype: int64

# %%
#Top #10 popular courses
t10 = df.sort_values(by = 'num_subscribers', ascending = False).head(10)
sns.barplot(y = 'course_title', x = 'num_subscribers', data = t10)
plt.xticks(rotation = 45)
plt.grid('True')

# %%
#on pie plot
Popular_courses = df.groupby('course_title')['num_subscribers'].sum().sort_values(ascending = False).head(10)
plt.pie(Popular_courses, normalize = True, autopct = '%1.1f%%', labels = Popular_courses.index)
# Out:
# ([<matplotlib.patches.Wedge at 0x7f88e1edee30>,
#   <matplotlib.patches.Wedge at 0x7f88e1edead0>,
#   <matplotlib.patches.Wedge at 0x7f88e1f041c0>,
#   <matplotlib.patches.Wedge at 0x7f88e1f05330>,
#   <matplotlib.patches.Wedge at 0x7f88e1f078e0>,
#   <matplotlib.patches.Wedge at 0x7f88e1f07dc0>,
#   <matplotlib.patches.Wedge at 0x7f88e1f07430>,
#   <matplotlib.patches.Wedge at 0x7f88e1f07fd0>,
#   <matplotlib.patches.Wedge at 0x7f88e1c5ff70>,
#   <matplotlib.patches.Wedge at 0x7f88e1c5fa00>],
#  [Text(0.8550051008182439, 0.6920738960362434, 'Learn HTML5 Programming From Scratch'),
#   Text(-0.21595121115649782, 1.0785940266847587, 'Coding for Entrepreneurs Basic'),
#   Text(-0.8702824052073926, 0.6727618710854799, 'The Web Developer Bootcamp'),
#   Text(-1.0988336297278796, 0.05064241482249344, 'Build Your First Website in 1 Week with HTML5 and CSS3'),
#   Text(-0.9388796369593342, -0.5731535809040271, 'The Complete Web Developer Course 2.0'),
#   Text(-0.50503406941605, -0.9772106163612144, 'Free Beginner Electric Guitar Lessons'),
#   Text(0.03202400382680852, -1.0995337480854785, 'Web Design for Web Developers: Build Beautiful Websites!'),
#   Text(0.5257625269693126, -0.9662162103974674, 'Learn Web Designing & HTML5/CSS3 Essentials in 4-Hours'),
#   Text(0.8832326069122266, -0.6556677223159857, 'Learn Javascript & JQuery From Scratch'),
#   Text(1.0754001067901513, -0.2313322509200381, 'Practical PHP: Master the Basics and Code Dynamic Websites')],
#  [Text(0.466366418628133, 0.3774948523834054, '21.7%'),
#   Text(-0.11779156972172607, 0.5883240145553228, '13.0%'),
#   Text(-0.47469949374948683, 0.3669610205920799, '9.8%'),
#   Text(-0.5993637980333888, 0.02762313535772369, '9.7%'),
#   Text(-0.5121161656141822, -0.31262922594765113, '9.2%'),
#   Text(-0.2754731287723909, -0.5330239725606624, '8.1%'),
#   Text(0.017467638450986464, -0.5997456807738973, '8.0%'),
#   Text(0.28677956016507955, -0.527027023853164, '7.0%'),
#   Text(0.4817632401339417, -0.35763693944508307, '6.8%'),
#   Text(0.5865818764309915, -0.12618122777456622, '6.7%')])

# %%
#Courses having highest rating
df.groupby('subject')['num_reviews'].sum().sort_values(ascending = False)
# Out:
# subject
# Web Development        430025
# Business Finance        75902
# Graphic Design          37070
# Musical Instruments     31724
# Name: num_reviews, dtype: int64

# %%
most_reviewed = df.groupby('subject')['num_reviews'].sum().sort_values(ascending = False)
sns.barplot(y = most_reviewed.index, x = most_reviewed.values, data = df)
plt.xticks(rotation = 45)
plt.grid('True')

# %%
#Effect of price on subscribers
sns.scatterplot(x = 'price', y = 'num_subscribers', data = df)
# Out:
# <Axes: xlabel='price', ylabel='num_subscribers'>

# %%
#There is no any decrement in number of subscribers due to pricing
